# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

# %%
batch_size = 2  # Puedes ajustar este valor según la disponibilidad de memoria
lr = 1e-5  # 0.0001
epochs = 40
height = 960
width = 540

# %%
dataset_path = os.path.join("dataset", "non-aug")
files_dir = os.path.join("Colab Notebooks", "files", "non-aug")
model_file = os.path.join(files_dir, "unet-non-aug.h5")
log_file = os.path.join(files_dir, "log-non-aug.csv")

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
create_dir(files_dir)

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

# %%
def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding="same")(inputs)
    x = tf.image.resize(x, [skip.shape[1], skip.shape[2]])  # Asegúrate de que las dimensiones coinciden
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape):
    inputs = Input(input_shape)
    """Encoder"""
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """Bridge"""
    b1 = conv_block(p4, 1024)

    """Decoder"""
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

# %%
def load_data(path):
    train_x = sorted(glob(os.path.join(path, "train", "images", "*")))
    train_y = sorted(glob(os.path.join(path, "train", "masks", "*")))
    valid_x = sorted(glob(os.path.join(path, "valid", "images", "*")))
    valid_y = sorted(glob(os.path.join(path, "valid", "masks", "*")))

    return (train_x, train_y), (valid_x, valid_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return tf.convert_to_tensor(x, dtype=tf.float32), tf.convert_to_tensor(y, dtype=tf.float32)

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 1])
    return x, y

# %%
def tf_dataset(x, y, batch=batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(dataset_path)
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
# Out:
# Train: 455 - 455
# Valid: 455 - 455

# %%
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

# %%
for x, y in valid_dataset:
    print(x.shape, y.shape)
# Out:
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)
# (1, 960, 540, 3) (1, 960, 540, 1)

# %%
input_shape = (height, width, 3)
model = build_unet(input_shape)

# %%
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 960, 540, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 960, 540, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 960, 540, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 960, 540, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 960, 540, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 960, 540, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 960, 540, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 480, 270, 64  0          ['activation_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 480, 270, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 480, 270, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 480, 270, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 480, 270, 12  147584      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 480, 270, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 480, 270, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 240, 135, 12  0          ['activation_21[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 240, 135, 25  295168      ['max_pooling2d_5[0][0]']
#                                 6)
#
#  batch_normalization_22 (BatchN  (None, 240, 135, 25  1024       ['conv2d_23[0][0]']
#  ormalization)                  6)
#
#  activation_22 (Activation)     (None, 240, 135, 25  0           ['batch_normalization_22[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 240, 135, 25  590080      ['activation_22[0][0]']
#                                 6)
#
#  batch_normalization_23 (BatchN  (None, 240, 135, 25  1024       ['conv2d_24[0][0]']
#  ormalization)                  6)
#
#  activation_23 (Activation)     (None, 240, 135, 25  0           ['batch_normalization_23[0][0]']
#                                 6)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 120, 67, 256  0          ['activation_23[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 120, 67, 512  1180160     ['max_pooling2d_6[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 120, 67, 512  2048       ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_24 (Activation)     (None, 120, 67, 512  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 120, 67, 512  2359808     ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 120, 67, 512  2048       ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 120, 67, 512  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 60, 33, 512)  0          ['activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 60, 33, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 60, 33, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 60, 33, 1024  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 60, 33, 1024  9438208     ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 60, 33, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 60, 33, 1024  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 120, 66, 512  2097664    ['activation_27[0][0]']
#  spose)                         )
#
#  tf.image.resize_4 (TFOpLambda)  (None, 120, 67, 512  0          ['conv2d_transpose_4[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 120, 67, 102  0           ['tf.image.resize_4[0][0]',
#                                 4)                                'activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 120, 67, 512  4719104     ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 120, 67, 512  2048       ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 120, 67, 512  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 120, 67, 512  2359808     ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 120, 67, 512  2048       ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 120, 67, 512  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 240, 134, 25  524544     ['activation_29[0][0]']
#  spose)                         6)
#
#  tf.image.resize_5 (TFOpLambda)  (None, 240, 135, 25  0          ['conv2d_transpose_5[0][0]']
#                                 6)
#
#  concatenate_5 (Concatenate)    (None, 240, 135, 51  0           ['tf.image.resize_5[0][0]',
#                                 2)                                'activation_23[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 240, 135, 25  1179904     ['concatenate_5[0][0]']
#                                 6)
#
#  batch_normalization_30 (BatchN  (None, 240, 135, 25  1024       ['conv2d_31[0][0]']
#  ormalization)                  6)
#
#  activation_30 (Activation)     (None, 240, 135, 25  0           ['batch_normalization_30[0][0]']
#                                 6)
#
#  conv2d_32 (Conv2D)             (None, 240, 135, 25  590080      ['activation_30[0][0]']
#                                 6)
#
#  batch_normalization_31 (BatchN  (None, 240, 135, 25  1024       ['conv2d_32[0][0]']
#  ormalization)                  6)
#
#  activation_31 (Activation)     (None, 240, 135, 25  0           ['batch_normalization_31[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 480, 270, 12  131200     ['activation_31[0][0]']
#  spose)                         8)
#
#  tf.image.resize_6 (TFOpLambda)  (None, 480, 270, 12  0          ['conv2d_transpose_6[0][0]']
#                                 8)
#
#  concatenate_6 (Concatenate)    (None, 480, 270, 25  0           ['tf.image.resize_6[0][0]',
#                                 6)                                'activation_21[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 480, 270, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_32 (BatchN  (None, 480, 270, 12  512        ['conv2d_33[0][0]']
#  ormalization)                  8)
#
#  activation_32 (Activation)     (None, 480, 270, 12  0           ['batch_normalization_32[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 480, 270, 12  147584      ['activation_32[0][0]']
#                                 8)
#
#  batch_normalization_33 (BatchN  (None, 480, 270, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  activation_33 (Activation)     (None, 480, 270, 12  0           ['batch_normalization_33[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 960, 540, 64  32832      ['activation_33[0][0]']
#  spose)                         )
#
#  tf.image.resize_7 (TFOpLambda)  (None, 960, 540, 64  0          ['conv2d_transpose_7[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 960, 540, 12  0           ['tf.image.resize_7[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 960, 540, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 960, 540, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 960, 540, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 960, 540, 64  36928       ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 960, 540, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 960, 540, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 960, 540, 1)  65          ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=1.0)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc"])

# %%
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
]

# %%
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/40
# 455/455 [==============================] - ETA: 0s - loss: 0.2672 - acc: 0.9253
# Epoch 1: val_loss improved from inf to 0.52245, saving model to Colab Notebooks\files\non-aug\unet-non-aug.h5
# 455/455 [==============================] - 301s 654ms/step - loss: 0.2672 - acc: 0.9253 - val_loss: 0.5225 - val_acc: 0.7645 - lr: 1.0000e-05
# Epoch 2/40
# 455/455 [==============================] - ETA: 0s - loss: 0.1568 - acc: 0.9588
# Epoch 2: val_loss improved from 0.52245 to 0.45351, saving model to Colab Notebooks\files\non-aug\unet-non-aug.h5
# 455/455 [==============================] - 465s 1s/step - loss: 0.1568 - acc: 0.9588 - val_loss: 0.4535 - val_acc: 0.8183 - lr: 1.0000e-05
# Epoch 3/40
# 455/455 [==============================] - ETA: 0s - loss: 0.1124 - acc: 0.9705
# Epoch 3: val_loss did not improve from 0.45351
# 455/455 [==============================] - 252s 553ms/step - loss: 0.1124 - acc: 0.9705 - val_loss: 0.6216 - val_acc: 0.7439 - lr: 1.0000e-05
# Epoch 4/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0907 - acc: 0.9762
# Epoch 4: val_loss did not improve from 0.45351
# 455/455 [==============================] - 192s 422ms/step - loss: 0.0907 - acc: 0.9762 - val_loss: 0.6649 - val_acc: 0.7520 - lr: 1.0000e-05
# Epoch 5/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0768 - acc: 0.9790
# Epoch 5: val_loss did not improve from 0.45351
# 455/455 [==============================] - 186s 409ms/step - loss: 0.0768 - acc: 0.9790 - val_loss: 0.8762 - val_acc: 0.7399 - lr: 1.0000e-05
# Epoch 6/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0678 - acc: 0.9807
# Epoch 6: val_loss did not improve from 0.45351
# 455/455 [==============================] - 271s 595ms/step - loss: 0.0678 - acc: 0.9807 - val_loss: 1.0162 - val_acc: 0.7343 - lr: 1.0000e-05
# Epoch 7/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0745 - acc: 0.9773
# Epoch 7: val_loss did not improve from 0.45351
# 455/455 [==============================] - 274s 603ms/step - loss: 0.0745 - acc: 0.9773 - val_loss: 0.5091 - val_acc: 0.8619 - lr: 1.0000e-06
# Epoch 8/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0677 - acc: 0.9797
# Epoch 8: val_loss did not improve from 0.45351
# 455/455 [==============================] - 292s 642ms/step - loss: 0.0677 - acc: 0.9797 - val_loss: 0.5221 - val_acc: 0.8566 - lr: 1.0000e-06
# Epoch 9/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0639 - acc: 0.9810
# Epoch 9: val_loss did not improve from 0.45351
# 455/455 [==============================] - 213s 468ms/step - loss: 0.0639 - acc: 0.9810 - val_loss: 0.5269 - val_acc: 0.8551 - lr: 1.0000e-06
# Epoch 10/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0617 - acc: 0.9816
# Epoch 10: val_loss did not improve from 0.45351
# 455/455 [==============================] - 261s 574ms/step - loss: 0.0617 - acc: 0.9816 - val_loss: 0.5270 - val_acc: 0.8545 - lr: 1.0000e-06
# Epoch 11/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0615 - acc: 0.9817
# Epoch 11: val_loss did not improve from 0.45351
# 455/455 [==============================] - 248s 545ms/step - loss: 0.0615 - acc: 0.9817 - val_loss: 0.5445 - val_acc: 0.8535 - lr: 1.0000e-07
# Epoch 12/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0604 - acc: 0.9820
# Epoch 12: val_loss did not improve from 0.45351
# 455/455 [==============================] - 334s 734ms/step - loss: 0.0604 - acc: 0.9820 - val_loss: 0.5402 - val_acc: 0.8542 - lr: 1.0000e-07
# Epoch 13/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0598 - acc: 0.9822
# Epoch 13: val_loss did not improve from 0.45351
# 455/455 [==============================] - 259s 569ms/step - loss: 0.0598 - acc: 0.9822 - val_loss: 0.5380 - val_acc: 0.8543 - lr: 1.0000e-07
# Epoch 14/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0594 - acc: 0.9824
# Epoch 14: val_loss did not improve from 0.45351
# 455/455 [==============================] - 261s 573ms/step - loss: 0.0594 - acc: 0.9824 - val_loss: 0.5364 - val_acc: 0.8543 - lr: 1.0000e-07
# Epoch 15/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0590 - acc: 0.9825
# Epoch 15: val_loss did not improve from 0.45351
# 455/455 [==============================] - 268s 588ms/step - loss: 0.0590 - acc: 0.9825 - val_loss: 0.5360 - val_acc: 0.8544 - lr: 1.0000e-08
# Epoch 16/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0589 - acc: 0.9825
# Epoch 16: val_loss did not improve from 0.45351
# 455/455 [==============================] - 343s 755ms/step - loss: 0.0589 - acc: 0.9825 - val_loss: 0.5351 - val_acc: 0.8544 - lr: 1.0000e-08
# Epoch 17/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0589 - acc: 0.9825
# Epoch 17: val_loss did not improve from 0.45351
# 455/455 [==============================] - 250s 550ms/step - loss: 0.0589 - acc: 0.9825 - val_loss: 0.5343 - val_acc: 0.8545 - lr: 1.0000e-08
# Epoch 18/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0588 - acc: 0.9826
# Epoch 18: val_loss did not improve from 0.45351
# 455/455 [==============================] - 263s 578ms/step - loss: 0.0588 - acc: 0.9826 - val_loss: 0.5337 - val_acc: 0.8546 - lr: 1.0000e-08
# Epoch 19/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0588 - acc: 0.9826
# Epoch 19: val_loss did not improve from 0.45351
# 455/455 [==============================] - 366s 804ms/step - loss: 0.0588 - acc: 0.9826 - val_loss: 0.5337 - val_acc: 0.8546 - lr: 1.0000e-09
# Epoch 20/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0588 - acc: 0.9826
# Epoch 20: val_loss did not improve from 0.45351
# 455/455 [==============================] - 316s 694ms/step - loss: 0.0588 - acc: 0.9826 - val_loss: 0.5336 - val_acc: 0.8546 - lr: 1.0000e-09
# Epoch 21/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0588 - acc: 0.9826
# Epoch 21: val_loss did not improve from 0.45351
# 455/455 [==============================] - 244s 536ms/step - loss: 0.0588 - acc: 0.9826 - val_loss: 0.5336 - val_acc: 0.8546 - lr: 1.0000e-09
# Epoch 22/40
# 455/455 [==============================] - ETA: 0s - loss: 0.0588 - acc: 0.9826
# Epoch 22: val_loss did not improve from 0.45351
# 455/455 [==============================] - 284s 625ms/step - loss: 0.0588 - acc: 0.9826 - val_loss: 0.5335 - val_acc: 0.8546 - lr: 1.0000e-09
